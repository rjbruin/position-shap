# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload
import sys
sys.path.append('../')

from published_models import GoogleResearchViT


class DebugExperiment():
    def __init__(self):
        self.train_loader = None
        self.val_loader = None
        self.n_samples = None

class DebugArgs():
    def __init__(self):
        self.data_root = '../data/EuroSAT/'
        self.batch_size = 32
        self.num_workers = 4
        self.dataset = 'eurosat'
        self.model = 'whatever'
        self.dataset_policy = 'GoogleResearchViT'
        self.internal_img_size = 224
    
exp = DebugExperiment()
args = DebugArgs()
GoogleResearchViT.dataset_policy(exp, args)

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch


def show(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1,2,0)))

# dataiter = iter(exp.train_loader)
dataiter = iter(exp.val_loader)
images, labels = dataiter.next()

fig, axs = plt.subplots(4, 4, figsize=(10,10))
for i in range(4):
    for j in range(4):
        print(torch.min(images[i*4+j]), torch.max(images[i*4+j]))
        axs[i,j].imshow(images[i*4+j].permute(1,2,0))
        axs[i,j].set_title(labels[i*4+j].item())
        axs[i,j].axis('off')

plt.show()
pass
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...
